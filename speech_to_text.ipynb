# %% [markdown]
# # Speech To Text

# %% [markdown]
# Speech to Text, also known as speech recognition, is a technology that converts spoken language into written text. By utilizing natural language processing algorithms and models, this technology enables the automatic transcription of spoken words into a readable text format.

# %%
import whisper
import gc 
import pandas as pd
import torch
import warnings
import os, sys
import json

from pydub import AudioSegment
from src.commons.common_tools import check_directories, parameters

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)
batch_size = 16 # reduce if low on GPU mem

# %%
def separateChannels(file, savePath):
    """
    Separate a stereo audio file into two mono channels and export as MP3 files.

    Parameters
    ----------
    file : str
        Path to the stereo audio file.
    savePath : str
        Path to the directory where separated mono audio files will be saved.

    Returns
    -------
    str, str
        Paths to the separated mono audio files.
    """
    stereoAudio = AudioSegment.from_file(file, format="mp3")

    monoAudios = stereoAudio.split_to_mono()
    
    audioRightFile = f"cliente.mp3"
    audioLeftFile = f"asesor.mp3"
    
    if not os.path.exists(savePath):
        os.mkdir(savePath)
        print(f"Se ha creado el directorio '{savePath}'")
    else:
        print(f"El directorio '{savePath}' ya existe")

    monoAudios[0].export(os.path.join(savePath, audioLeftFile), format="mp3")
    monoAudios[1].export(os.path.join(savePath, audioRightFile), format="mp3")
    
    return os.path.join(savePath, audioLeftFile), os.path.join(savePath, audioRightFile)
    
def whisperTranscription(file):
    """
    Perform speech transcription using the Whisper model.
    
    Parameters
    ----------
    file : str
        Path to the audio file for transcription.
    
    Returns
    -------
    dict
        Transcription results including segments, start times, end times, and transcribed text.
    """
    model = whisper.load_model("large")
    
    audio = whisper.load_audio(file)
    result = model.transcribe(
        audio,
        language ="Spanish",
        word_timestamps=True
    )
    gc.collect(); torch.cuda.empty_cache()
    return result

def filterModelMistakes(df):
    """
    Filter transcribed segments based on text length and duration.

    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame containing transcribed segments with timing and text information.

    Returns
    -------
    pandas.DataFrame
        DataFrame with additional columns for timing analysis and validity checks.
    """
    df = df.assign(T_DELTA=df.end-df.start)
    df = df.assign(WORD_LENGHT=df.text.str.split(' {1,}').str.len())
    df = df.assign(RATIO=df.WORD_LENGHT/df.T_DELTA)
    df = df.assign(VALID=df.RATIO<20)
    return df

def concatTranscript(asesor, cliente):
    """
    Concatenates and processes transcriptions of advisor and client.

    Parameters
    ----------
    asesor : dict
        Transcription of the advisor.
    cliente : dict
        Transcription of the client.

    Returns
    -------
    pandas.DataFrame
        Concatenated and processed transcriptions.
    """
    transcriptCliente = pd.DataFrame.from_dict(cliente['segments'])
    transcriptCliente = transcriptCliente.assign(speaker='cliente')
    transcriptCliente[['start', 'end', 'text', 'speaker']]

    transcriptAsesor = pd.DataFrame.from_dict(asesor['segments'])
    transcriptAsesor = transcriptAsesor.assign(speaker='asesor')
    transcriptAsesor[['start', 'end', 'text', 'speaker']]

    concat = pd.concat([transcriptCliente, transcriptAsesor])[['start', 'end', 'text', 'speaker']].sort_values('start')

    return filterModelMistakes(concat)

def exportText(df, filePath, fileName):
    """
    Export transcribed text to a text file.

    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame containing transcribed segments with speaker and text information.
    filePath : str
        Path to the directory where the text file will be saved.
    fileName : str
        Name of the text file.

    Returns
    -------
    None
    """
    with open(os.path.join(filePath, fileName), 'w') as file:
        for i, row in df.iterrows():
            line = f"{row['speaker']}: {row['text']}\n"
            file.write(line)

# %%
check_directories(parameters)
with open(os.path.join(parameters['parametric'], 'speech2text.json'), 'r') as f:
        parametric = json.loads(f.read())

# %%
nameFolder = '.'.join(parametric['audio_file'].split('.')[:-1])

audioFile = os.path.join(parameters['audios'], parametric['audio_file'])

speakersPath = os.path.join(parameters['speakers'], nameFolder)

# %%
cliente, asesor = separateChannels(audioFile, speakersPath)
# Out:
# El directorio '/notebooks/03_output/speech_to_text/audios_speakers/vys_01TUP21LACA578J11C4H5B5AES1AV3TM_2023-07-07_19-53-36 Chacon Ramirez Jurany' ya existe

# %%
resultTranscriptCliente = whisperTranscription(cliente)
resultTranscriptAsesor = whisperTranscription(asesor)
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [01:43<00:00, 29.8MiB/s]

# %%
df_transcript = concatTranscript(resultTranscriptCliente, resultTranscriptAsesor)
df_transcript
# Out:
#      start     end                                               text  \
# 0     0.76    2.68            Gracias, si tengo el número de Radical.
# 0     4.58    9.36   Muy buena tarde, bienvenido a la línea del Ba...
# 1     6.38    7.86                    ¿Radical es el que ha dedicado?
# 2     8.20    9.12                            ¿Es el que ha dedicado?
# 1     9.40   16.62   luego con el señor Sergio. ¿Vos saludarlo con...
# 3    11.66   12.10                            ¿Es el que ha dedicado?
# 4    12.10   12.64                                        Sí, señora.
# 5    13.90   14.52                                          ¿Cuál es?
# 2    16.62   17.12                                               ¿Sí?
# 6    17.52   26.10   Gracias, mire, un favor, es que yo llamo el m...
# 7    26.10   28.94           porque a mí me genera reparar los incos.
# 3    27.12   27.18                                               ¿Sí?
# 8    29.20   33.04   Me hicieron todo el proceso de como media hor...
# 9    33.04   34.18                          el asesor en ese momento.
# 10   34.66   39.16   Me dijo, sí, señor, la próxima cuota pague de...
# 11   39.16   40.80                    a partir de julio queda normal.
# 12   41.52   43.98   Yo la verdadera confieso que me llevo un corr...
# 13   43.98   48.74   Mora y pues efectivamente revisó el estatus e...
# 14   48.74   50.50                       que está para el 4 de julio.
# 15   51.04   58.72   Y el mes pasado, o sea, para junio, yo hice e...
# 16   59.24   64.68   precisamente para encontrar ahorita en junio ...
# 17   64.88   68.38   Yo no entiendo por qué no se pudo hacer ese a...
# 4    69.52   73.80   ¿Estabas en Mora cuando hicieron el proyecto ...
# 18   71.24   72.98                             No, no estaba en mora.
# 19   73.66   82.02   No, yo lo hice en mayo y no estaba en mora y ...
# 20   82.02   83.28                                          para eso.
# 5    85.50   87.52   ¿Cuál crédito es un crédito de vehículo, verdad?
# 21   86.64   87.56                                         ¿En junio?
# 22   87.94   93.72   Sí, el pago pasado lo hice el 30 de mayo, lo ...
# 23   93.80   95.58          El mes de junio y lo pagué el 30 de mayo.
# 24   96.84  101.68   Y se suponía que iba a quedar a partir de jul...
# 6   106.32  110.26   De acuerdo, en un momento lo ligamos y ya est...
# 25  125.58  126.80                                         Sí, claro.
# 7   137.32  144.72   Vale, lo que pasa es que aparece el registro ...
# 26  142.94  151.70                Claro, y yo mandé el correo y todo.
# 8   144.88  147.90   ¿Tú tienes de pronto la póliza con alguna otr...
# 9   148.74  149.62                                 Y no con nosotros.
# 10  153.44  154.50                                         El correo.
# 11  154.80  155.30                                      ¿Cuál correo?
# 27  155.74  161.02   El correo va a descender al banco que yo hice...
# 12  162.70  167.40   Pero nuestro correo es por la página del banc...
# 13  168.48  172.98   Es por el botón contractor del banco, debes h...
# 14  172.98  180.26   vencida o como tal la poliza, no te permiten ...
# 28  181.80  185.62   Pero se arregló porque entonces la persona qu...
# 29  185.62  188.80   tiempo porque no fue capaz de dar una informa...
# 15  188.92  194.80   Ahí te dice el proceso, lo que pasa es que la...
# 30  191.22  192.42                    Por eso está dando información.
# 16  194.80  199.06   de servicio al cliente te hace el proceso y y...
# 17  199.06  205.76   y de la otra área es que dan la respuesta par...
# 18  205.76  211.28   yo estoy ingresando a la solicitud que se rea...
# 19  211.28  215.72   pudo proceder debido a que al momento aparece...
# 20  216.78  223.02   Entonces ya como tal debes hacer nuevamente e...
# 31  216.80  220.00                       ¿Qué es lo que está pasando?
# 21  223.02  228.38   la póliza que tengas con la otra compañía a t...
# 32  225.54  226.76                       ¿Qué es lo que está pasando?
# 33  227.70  228.58                       ¿Qué es lo que está pasando?
# 22  228.38  234.92   de accidentes de la página para que no haya i...
# 34  228.96  231.10                       ¿Qué es lo que está pasando?
# 35  231.90  234.40                       ¿Qué es lo que está pasando?
# 23  234.92  239.88   conteste, de que está aprobado, puedes volver...
# 36  237.04  238.26                       ¿Qué es lo que está pasando?
# 37  238.74  239.54                       ¿Qué es lo que está pasando?
# 24  239.88  241.60                       gestión del cambio de corte.
# 38  239.96  240.26                       ¿Qué es lo que está pasando?
# 39  240.80  241.32                       ¿Qué es lo que está pasando?
# 40  241.86  242.60                       ¿Qué es lo que está pasando?
# 41  244.42  245.44                       ¿Qué es lo que está pasando?
# 44  245.60  245.60
# 43  245.60  245.60
# 45  245.60  247.22                    Y eso es por la página interna.
# 42  245.60  245.60
# 25  247.60  254.48   Si generas por la página o en un crédito dent...
# 46  248.76  250.20                         Y que tengo que enviar yo.
# 26  254.48  256.24           las oficinas especializadas de vehículo.
# 47  257.82  259.52                       No, qué horrible, la verdad.
# 48  260.66  265.14   Y eso, además de la cuota, que no la puedo mo...
# 49  265.32  266.46                    ¿impacta en algo en el crédito?
# 27  269.48  274.70                        ¿Qué?, en Endorro, de la...
# 50  271.16  272.62                             Sí, está bien hacerlo.
# 28  274.70  277.32         Sí claro, pueden empezar a cobrar entonces
# 51  275.60  305.58   Pero bueno, desde luego ya reducir al definit...
# 29  277.32  279.18           la póliza con nosotros porque el crédito
# 30  279.18  281.30   de vehículos del CIO si tiene que tener una p...
# 31  281.82  283.60                entonces vería un aumento reflejado
# 32  283.60  284.52                              el valor de tu cuota.
# 33  304.08  310.38   Sí señor, mire, quiere que se haga la carta, ...
# 53  305.58  306.56                                      de la ciudad.
# 52  305.58  305.58
# 54  307.66  308.28                                       Y el pueblo.
# 34  310.38  319.96   Debe solicitar el endoso, así se llama el pro...
# 55  314.12  315.36                                       Y el pueblo.
# 56  320.18  321.06                                       Y el pueblo.
# 35  320.62  322.54                   La poliza de todo riesgo, ¿vale?
# 57  321.06  321.06
# 36  323.18  329.34   Tienes que poner la carátula, que vendría sie...
# 58  323.20  324.10                                       Y el pueblo.
# 59  327.78  328.62                                       Y el pueblo.
# 37  329.46  332.36   donde tenga las características que tiene esa...
# 60  329.60  329.60
# 61  330.52  331.26                                       Y el pueblo.
# 62  332.20  332.50                                       Y el pueblo.
# 63  332.96  333.88                                       Y el pueblo.
# 38  333.32  337.72   que para que sea aceptada con nosotros, pues ...
# 68  334.78  335.04                                       Y el pueblo.
# 64  334.78  334.78
# 65  334.78  334.78
# 66  334.78  334.78
# 67  334.78  334.78
# 69  335.04  335.04
# 70  335.04  335.04
# 71  335.04  335.08                                       Y el pueblo.
# 80  335.08  335.18                                       Y el pueblo.
# 73  335.08  335.08
# 74  335.08  335.08
# 75  335.08  335.08
# 76  335.08  335.08
# 77  335.08  335.08
# 78  335.08  335.08
# 79  335.08  335.08
# 72  335.08  335.08
# 39  337.72  341.30   que es tener las mismas características de la...
# 40  344.06  348.64   El desprendible de pago, donde conste que tú ...
# 41  351.20  359.26   y ya, con la solicitud debe de ser específico...
# 42  359.26  362.32         póliza, ¿vale?, para que te puedan ayudar.
# 43  364.52  384.88   Hola. Hola, ¿me escucha? ¿Señor Sergio? Hola,...
# 44  395.64  398.18                                      Señor Sergio.
# 81  401.90  403.16                                    Muchas gracias.
#
#     speaker  T_DELTA  WORD_LENGHT       RATIO  VALID
# 0   cliente     1.92            8    4.166667   True
# 0    asesor     4.78           16    3.347280   True
# 1   cliente     1.48            7    4.729730   True
# 2   cliente     0.92            6    6.521739   True
# 1    asesor     7.22           16    2.216066   True
# 3   cliente     0.44            6   13.636364   True
# 4   cliente     0.54            3    5.555556   True
# 5   cliente     0.62            3    4.838710   True
# 2    asesor     0.50            2    4.000000   True
# 6   cliente     8.58           30    3.496503   True
# 7   cliente     2.84            9    3.169014   True
# 3    asesor     0.06            2   33.333333  False
# 8   cliente     3.84           12    3.125000   True
# 9   cliente     1.14            6    5.263158   True
# 10  cliente     4.50           13    2.888889   True
# 11  cliente     1.64            7    4.268293   True
# 12  cliente     2.46           13    5.284553   True
# 13  cliente     4.76           13    2.731092   True
# 14  cliente     1.76            8    4.545455   True
# 15  cliente     7.68           25    3.255208   True
# 16  cliente     5.44           18    3.308824   True
# 17  cliente     3.50           16    4.571429   True
# 4    asesor     4.28           11    2.570093   True
# 18  cliente     1.74            6    3.448276   True
# 19  cliente     8.36           21    2.511962   True
# 20  cliente     1.26            3    2.380952   True
# 5    asesor     2.02            9    4.455446   True
# 21  cliente     0.92            3    3.260870   True
# 22  cliente     5.78           14    2.422145   True
# 23  cliente     1.78           12    6.741573   True
# 24  cliente     4.84           16    3.305785   True
# 6    asesor     3.94           12    3.045685   True
# 25  cliente     1.22            3    2.459016   True
# 7    asesor     7.40           17    2.297297   True
# 26  cliente     8.76            9    1.027397   True
# 8    asesor     3.02           11    3.642384   True
# 9    asesor     0.88            5    5.681818   True
# 10   asesor     1.06            3    2.830189   True
# 11   asesor     0.50            3    6.000000   True
# 27  cliente     5.28           17    3.219697   True
# 12   asesor     4.70           18    3.829787   True
# 13   asesor     4.50           17    3.777778   True
# 14   asesor     7.28           15    2.060440   True
# 28  cliente     3.82           16    4.188482   True
# 29  cliente     3.18           11    3.459119   True
# 15   asesor     5.88           19    3.231293   True
# 30  cliente     1.20            6    5.000000   True
# 16   asesor     4.26           16    3.755869   True
# 17   asesor     6.70           19    2.835821   True
# 18   asesor     5.52           18    3.260870   True
# 19   asesor     4.44           12    2.702703   True
# 20   asesor     6.24           16    2.564103   True
# 31  cliente     3.20            7    2.187500   True
# 21   asesor     5.36           16    2.985075   True
# 32  cliente     1.22            7    5.737705   True
# 33  cliente     0.88            7    7.954545   True
# 22   asesor     6.54           18    2.752294   True
# 34  cliente     2.14            7    3.271028   True
# 35  cliente     2.50            7    2.800000   True
# 23   asesor     4.96           16    3.225806   True
# 36  cliente     1.22            7    5.737705   True
# 37  cliente     0.80            7    8.750000   True
# 24   asesor     1.72            6    3.488372   True
# 38  cliente     0.30            7   23.333333  False
# 39  cliente     0.52            7   13.461538   True
# 40  cliente     0.74            7    9.459459   True
# 41  cliente     1.02            7    6.862745   True
# 44  cliente     0.00            1         inf  False
# 43  cliente     0.00            1         inf  False
# 45  cliente     1.62            8    4.938272   True
# 42  cliente     0.00            1         inf  False
# 25   asesor     6.88           18    2.616279   True
# 46  cliente     1.44            7    4.861111   True
# 26   asesor     1.76            6    3.409091   True
# 47  cliente     1.70            6    3.529412   True
# 48  cliente     4.48           12    2.678571   True
# 49  cliente     1.14            7    6.140351   True
# 27   asesor     5.22            6    1.149425   True
# 50  cliente     1.46            5    3.424658   True
# 28   asesor     2.62            8    3.053435   True
# 51  cliente    29.98           18    0.600400   True
# 29   asesor     1.86            8    4.301075   True
# 30   asesor     2.12           11    5.188679   True
# 31   asesor     1.78            6    3.370787   True
# 32   asesor     0.92            6    6.521739   True
# 33   asesor     6.30           20    3.174603   True
# 53  cliente     0.98            4    4.081633   True
# 52  cliente     0.00            1         inf  False
# 54  cliente     0.62            4    6.451613   True
# 34   asesor     9.58           18    1.878914   True
# 55  cliente     1.24            4    3.225806   True
# 56  cliente     0.88            4    4.545455   True
# 35   asesor     1.92            7    3.645833   True
# 57  cliente     0.00            1         inf  False
# 36   asesor     6.16           17    2.759740   True
# 58  cliente     0.90            4    4.444444   True
# 59  cliente     0.84            4    4.761905   True
# 37   asesor     2.90            9    3.103448   True
# 60  cliente     0.00            1         inf  False
# 61  cliente     0.74            4    5.405405   True
# 62  cliente     0.30            4   13.333333   True
# 63  cliente     0.92            4    4.347826   True
# 38   asesor     4.40           13    2.954545   True
# 68  cliente     0.26            4   15.384615   True
# 64  cliente     0.00            1         inf  False
# 65  cliente     0.00            1         inf  False
# 66  cliente     0.00            1         inf  False
# 67  cliente     0.00            1         inf  False
# 69  cliente     0.00            1         inf  False
# 70  cliente     0.00            1         inf  False
# 71  cliente     0.04            4  100.000000  False
# 80  cliente     0.10            4   40.000000  False
# 73  cliente     0.00            1         inf  False
# 74  cliente     0.00            1         inf  False
# 75  cliente     0.00            1         inf  False
# 76  cliente     0.00            1         inf  False
# 77  cliente     0.00            1         inf  False
# 78  cliente     0.00            1         inf  False
# 79  cliente     0.00            1         inf  False
# 72  cliente     0.00            1         inf  False
# 39   asesor     3.58           12    3.351955   True
# 40   asesor     4.58           16    3.493450   True
# 41   asesor     8.06           17    2.109181   True
# 42   asesor     3.06            8    2.614379   True
# 43   asesor    20.36           10    0.491159   True
# 44   asesor     2.54            3    1.181102   True
# 81  cliente     1.26            3    2.380952   True

# %%
exportText(df_transcript, parameters['transcription'], parametric['transcript_file'])
