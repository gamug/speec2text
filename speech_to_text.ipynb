# %% [markdown]
# # Speech To Text

# %% [markdown]
# Speech to Text, also known as speech recognition, is a technology that converts spoken language into written text. By utilizing natural language processing algorithms and models, this technology enables the automatic transcription of spoken words into a readable text format.

# %%
import whisperx
import gc 
import pandas as pd
import torch
import warnings
import os, sys

from pydub import AudioSegment
from src.commons.common_tools import check_directories

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
device = "cuda" 
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)
batch_size = 16 # reduce if low on GPU mem

parameters = {
    'path': os.path.dirname(sys.path[0]),
    'path_in': os.path.join(os.path.dirname(sys.path[0]), '01_data'),
    'path_out': os.path.join(os.path.dirname(sys.path[0]), '03_output'),
    'curated': os.path.join(os.path.dirname(sys.path[0]), '01_data', 'curated'),
    'matching': os.path.join(os.path.dirname(sys.path[0]), '01_data', 'matching_dbs'),
    'topic_modeling': os.path.join(os.path.dirname(sys.path[0]), '03_output', 'topic_modeling'),
    'speech': os.path.join(os.path.dirname(sys.path[0]), '03_output', 'speech_to_text'),
    'audios': os.path.join(sys.path[0], '01_data', 'audios_ccenter'),
    'speakers': os.path.join(sys.path[0], '03_output', 'speech_to_text', 'audios_speakers'),
    'transcription': os.path.join(sys.path[0], '03_output', 'speech_to_text', 'transcription')
}

# %%
def separateChannels(file, savePath):
    stereoAudio = AudioSegment.from_file(file, format="mp3")

    monoAudios = stereoAudio.split_to_mono()
    
    audioRightFile = "speaker_cliente.mp3"
    audioLeftFile = "speaker_asesor.mp3"

    monoAudios[0].export(os.path.join(savePath, audioLeftFile), format="mp3")
    monoAudios[1].export(os.path.join(savePath, audioRightFile), format="mp3")
    
    return os.path.join(savePath, audioLeftFile), os.path.join(savePath, audioRightFile)
    
def whisperTranscription(file):
    model = whisperx.load_model("large-v2", device, compute_type=compute_type)

    audio = whisperx.load_audio(file)
    result = model.transcribe(audio, batch_size=batch_size, language="es")

    gc.collect(); torch.cuda.empty_cache(); del model
    
    model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
    result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
    return result

def filterModelMistakes(df):
    df = df.assign(T_DELTA=df.end-df.start)
    df = df.assign(WORD_LENGHT=df.text.str.split(' {1,}').str.len())
    df = df.assign(RATIO=df.WORD_LENGHT/df.T_DELTA)
    df = df.assign(VALID=df.RATIO<20)
    return df

def concatTranscript(asesor, cliente):
    transcriptCliente = pd.DataFrame.from_dict(cliente['segments'])
    transcriptCliente = transcriptCliente.assign(speaker='cliente')
    transcriptCliente[['start', 'end', 'text', 'speaker']]

    transcriptAsesor = pd.DataFrame.from_dict(asesor['segments'])
    transcriptAsesor = transcriptAsesor.assign(speaker='asesor')
    transcriptAsesor[['start', 'end', 'text', 'speaker']]

    concat = pd.concat([transcriptCliente, transcriptAsesor])[['start', 'end', 'text', 'speaker']].sort_values('start')

    return filterModelMistakes(concat)

def exportText(df, filePath, fileName):
    with open(os.path.join(filePath, fileName), 'w') as file:
        for i, row in df.iterrows():
            line = f"{row['speaker']}: {row['text']}\n"
            file.write(line)

# %%
check_directories(parameters)

# %%
audioFile = os.path.join(parameters['audios'], "test_audio_1.mp3")
speakersPath = os.path.join(parameters['speakers'], "test_audio_1")

# %%
cliente, asesor = separateChannels(audioFile, speakersPath)

# %%
resultTranscriptCliente = whisperTranscription(cliente)
resultTranscriptAsesor = whisperTranscription(asesor)
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.6. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu117. Bad things might happen unless you revert torch to 1.x.
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_voxpopuli_base_10k_asr_es.pt" to /root/.cache/torch/hub/checkpoints/wav2vec2_voxpopuli_base_10k_asr_es.pt
# 100%|██████████| 360M/360M [00:01<00:00, 374MB/s]
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.6. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu117. Bad things might happen unless you revert torch to 1.x.

# %%
df_transcript = concatTranscript(resultTranscriptCliente, resultTranscriptAsesor)
df_transcript
# Out:
#       start      end                                               text  \
# 0     1.783   12.610               A ver si tengo el número de Radical.
# 0     4.946    8.207   Muy buena tarde, bienvenido a las líneas del ...
# 1     8.207   13.570  Habla con Yorami Shapono, luego con el señor S...
# 1    12.610   17.733                                        Sí, señora.
# 2    13.570   15.652                ¿Cómo puede ayudarle el día de hoy?
# 2    17.733   18.133                                           Gracias.
# 3    18.133   18.734                                    Mira, un favor.
# 4    18.734   26.199  Es que yo llamo el mes de mayo para que me hic...
# 5    26.199   27.820             Porque a mí en general me pagan los 5.
# 6    29.664   40.848   me hicieron todo el proceso de como media hor...
# 3    29.948   30.088                                    ... ... ... ...
# 7    40.848   51.491  Yo la verdadera confianza que me llevo un corr...
# 8    51.491   58.013  Y el mes pasado, o sea, para junio, yo hice el...
# 9    59.278   65.222   Precisamente para comprar ahorita en junio a ...
# 10   65.222   68.445  No entiendo por qué no se pudo hacer esa modif...
# 11   68.445   74.029                             No, no estaba en mora.
# 4    69.765   73.768   ¿Estabas en Muro cuando hicieron el proyecto ...
# 12   74.029   74.789                                                No.
# 13   74.789   77.331          Esto lo hice en mayo y no estaba en mora.
# 14   77.331   83.655  Y en junio pagué, junio lo pagué en mayo tambi...
# 15   83.655   83.796                                                Sí.
# 5    85.930  106.714     El crédito es un crédito de vehículo, ¿verdad?
# 16   89.589   93.892   Mira, el pago pasado lo hice el 30 de mayo, o...
# 17   93.892   97.374            El mes de junio lo pagué el 30 de mayo.
# 18   97.374  101.197  Y se suponía que iba a quedar a partir de juli...
# 19  101.197  101.297                                               ¿Sí?
# 20  101.297  101.617                                         Ah, bueno.
# 6   106.714  110.095  De acuerdo, en un momento le damos y ya está c...
# 7   113.443  117.206                          Vale, lo que pasa es que,
# 21  118.775  119.195                                         ¿Quién es?
# 22  119.195  119.556                                         ¿Quién es?
# 23  119.556  121.757                                         ¿Quién es?
# 24  121.757  123.399                                         ¿Quién es?
# 25  123.399  124.360                                         ¿Quién es?
# 26  124.360  124.800                                         ¿Quién es?
# 27  124.800  125.100                                         ¿Quién es?
# 8   139.849  144.850   Aparece el registro de la póliza del seguro v...
# 9   144.850  148.891  ¿Tú tienes de pronto la póliza con alguna otra...
# 28  148.559  156.304    Claro y yo mandé el, yo mandé el correo y todo.
# 10  148.891  153.933                                ¿Y no con nosotros?
# 11  153.933  154.773                                         El correo.
# 12  154.773  163.095                                      ¿Cuál correo?
# 29  156.304  160.788  El correo era el banco que yo hice en cambio d...
# 13  163.095  167.356  Pero no es por correo, es por la página del ba...
# 14  168.688  170.390             es por el botón contáctenos del banco.
# 15  170.390  189.428  Debes hacer el proceso porque al tener la gara...
# 30  182.193  190.117   Pero se arregla porque entonces el asesor que...
# 16  189.428  190.989                            Ahí te dice el proceso.
# 31  190.117  193.559              Por eso todavía no me informó de eso.
# 17  190.989  193.732  Lo que pasa es que la persona de servicio al c...
# 18  194.647  199.110   la persona de servicio al cliente te hace el ...
# 19  199.110  205.273  Y de la otra área es que dan la respuesta para...
# 20  205.273  216.900  En este momento yo estoy ingresando a la solic...
# 21  216.900  222.483  Entonces ya como tal, debes hacer nuevamente e...
# 32  218.978  220.399                    Y eso es por la página interna.
# 22  222.975  233.437   de la póliza que tengas con la otra compañía ...
# 23  233.437  247.900  Luego de que ya eso se te conteste, de que est...
# 24  247.900  250.941     Si vienes por la página o en un crédito dentro
# 33  249.010  258.818                         y que tengo que enviar yo.
# 25  253.043  269.734   ¿Qué sería como tal una de nuestras oficinas ...
# 34  258.818  265.303  Y eso, además de la cuota, es que no la puedo ...
# 35  265.303  271.307                    ¿Impacta en algo en el crédito?
# 26  269.734  270.135                                              ¿Qué?
# 27  270.135  275.978                    ¿El endorso de la... Sí, claro.
# 36  271.307  272.828                             Sí, está bien hacerlo.
# 28  275.978  281.322  Pueden empezar a cobrar entonces la póliza con...
# 37  278.911  294.018   No, pues diría la verdad que no hay informe a...
# 29  281.877  284.598   entonces verías un aumento reflejado en el va...
# 30  284.598  307.309      Sí señor, mire, ¿quiere que se haga la carta?
# 38  294.018  303.562  Entonces, yo intenté y quedé, y ahí dice que e...
# 31  307.309  310.310           Pues con su puño y letra la debe firmar.
# 32  310.863  320.792   Debe de solicitar el endoso, así se llama el ...
# 39  312.668  314.768                                Y me decían que no.
# 40  314.768  315.489                                Y yo, ay, no puedo.
# 41  315.489  316.229                                No puedo, no puedo.
# 42  316.229  317.509                                          No puedo.
# 43  317.509  318.189                                          No puedo.
# 44  318.189  319.170                                          No puedo.
# 45  319.170  319.710                                          No puedo.
# 46  319.710  320.370                                          No puedo.
# 47  320.370  320.730                                          No puedo.
# 48  320.730  321.290                                          No puedo.
# 33  320.792  323.635                   La poliza de todo riesgo, ¿vale?
# 49  321.290  322.030                                          No puedo.
# 50  322.030  322.490                                          No puedo.
# 51  322.490  323.791                                          No puedo.
# 34  323.635  332.363  Tienes que poner la carátula, que vendría sien...
# 35  333.553  344.382   que para que te acepta con nosotros pues debe...
# 36  344.382  362.096  El desprendible de pago, donde conste que tú e...
# 37  370.566  376.049                                 Hola, ¿me escucha?
# 38  376.049  383.995                                     ¿Señor Sergio?
# 39  383.995  384.915                               Hola, ¿señor Sergio?
# 40  397.599  398.260                                      Señor Sergio.
# 52  402.612  402.989                                            No, no.
#
#     speaker  T_DELTA  WORD_LENGHT      RATIO  VALID
# 0   cliente   10.827            9   0.831255   True
# 0    asesor    3.261           12   3.679853   True
# 1    asesor    5.363            9   1.678165   True
# 1   cliente    5.123            2   0.390396   True
# 2    asesor    2.082            7   3.362152   True
# 2   cliente    0.400            1   2.500000   True
# 3   cliente    0.601            3   4.991681   True
# 4   cliente    7.465           25   3.348962   True
# 5   cliente    1.621            9   5.552128   True
# 6   cliente   11.184           36   3.218884   True
# 3    asesor    0.140            5  35.714286  False
# 7   cliente   10.643           32   3.006671   True
# 8   cliente    6.522           24   3.679853   True
# 9   cliente    5.944           18   3.028264   True
# 10  cliente    3.223           10   3.102699   True
# 11  cliente    5.584            5   0.895415   True
# 4    asesor    4.003           11   2.747939   True
# 12  cliente    0.760            1   1.315789   True
# 13  cliente    2.542           10   3.933910   True
# 14  cliente    6.324           13   2.055661   True
# 15  cliente    0.141            1   7.092199   True
# 5    asesor   20.784            9   0.433025   True
# 16  cliente    4.303           16   3.718336   True
# 17  cliente    3.482           10   2.871913   True
# 18  cliente    3.823           16   4.185195   True
# 19  cliente    0.100            1  10.000000   True
# 20  cliente    0.320            2   6.250000   True
# 6    asesor    3.381           11   3.253475   True
# 7    asesor    3.763            7   1.860218   True
# 21  cliente    0.420            3   7.142857   True
# 22  cliente    0.361            2   5.540166   True
# 23  cliente    2.201            2   0.908678   True
# 24  cliente    1.642            2   1.218027   True
# 25  cliente    0.961            2   2.081165   True
# 26  cliente    0.440            2   4.545455   True
# 27  cliente    0.300            2   6.666667   True
# 8    asesor    5.001           10   1.999600   True
# 9    asesor    4.041           10   2.474635   True
# 28  cliente    7.745           12   1.549387   True
# 10   asesor    5.042            4   0.793336   True
# 11   asesor    0.840            2   2.380952   True
# 12   asesor    8.322            2   0.240327   True
# 29  cliente    4.484           14   3.122212   True
# 13   asesor    4.261           19   4.459047   True
# 14   asesor    1.702            8   4.700353   True
# 15   asesor   19.038           25   1.313163   True
# 30  cliente    7.924           26   3.281171   True
# 16   asesor    1.561            5   3.203075   True
# 31  cliente    3.442            8   2.324230   True
# 17   asesor    2.743           11   4.010208   True
# 18   asesor    4.463           18   4.033162   True
# 19   asesor    6.163           15   2.433880   True
# 20   asesor   11.627           31   2.666208   True
# 21   asesor    5.583           13   2.328497   True
# 32  cliente    1.421            8   5.629838   True
# 22   asesor   10.462           27   2.580768   True
# 23   asesor   14.463           27   1.866833   True
# 24   asesor    3.041           10   3.288392   True
# 33  cliente    9.808            7   0.713703   True
# 25   asesor   16.691           12   0.718950   True
# 34  cliente    6.485           12   1.850424   True
# 35  cliente    6.004            6   0.999334   True
# 26   asesor    0.401            1   2.493766   True
# 27   asesor    5.843            6   1.026870   True
# 36  cliente    1.521            4   2.629849   True
# 28   asesor    5.344           20   3.742515   True
# 37  cliente   15.107           12   0.794334   True
# 29   asesor    2.721           12   4.410143   True
# 30   asesor   22.711            9   0.396284   True
# 38  cliente    9.544           17   1.781224   True
# 31   asesor    3.001            9   2.999000   True
# 32   asesor    9.929           19   1.913586   True
# 39  cliente    2.100            6   2.857143   True
# 40  cliente    0.721            5   6.934813   True
# 41  cliente    0.740            4   5.405405   True
# 42  cliente    1.280            2   1.562500   True
# 43  cliente    0.680            2   2.941176   True
# 44  cliente    0.981            2   2.038736   True
# 45  cliente    0.540            2   3.703704   True
# 46  cliente    0.660            2   3.030303   True
# 47  cliente    0.360            2   5.555556   True
# 48  cliente    0.560            2   3.571429   True
# 33   asesor    2.843            6   2.110447   True
# 49  cliente    0.740            2   2.702703   True
# 50  cliente    0.460            2   4.347826   True
# 51  cliente    1.301            2   1.537279   True
# 34   asesor    8.728           24   2.749771   True
# 35   asesor   10.829           25   2.308616   True
# 36   asesor   17.714           39   2.201648   True
# 37   asesor    5.483            4   0.729528   True
# 38   asesor    7.946            2   0.251699   True
# 39   asesor    0.920            3   3.260870   True
# 40   asesor    0.661            3   4.538578   True
# 52  cliente    0.377            3   7.957560   True

# %%
exportText(df_transcript, parameters['transcription'], "transcript_1.txt")
